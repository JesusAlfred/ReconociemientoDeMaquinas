# %%
import numpy as np
from PIL import Image
from statistics import mode
import operator as op
import os

# %%
# Dir where images are stored
imageDir = "../../img"

# Dir where processed images should be saved
outputDir = "../../cleanedImg"

# How close to the background color does a pixel have to be to be removed
colorThreshold = 65

# How much of the image has to be the same color to be considered the background
backgroundColorPercentage = 0.15

bgRemoveCounter = 0
totalCounter = 0

# %%
def equalsThreshold(c1, c2, threshold):
    return (
        c2[0] >= c1[0] - threshold and c2[0] <= c1[0] + threshold and
        c2[1] >= c1[1] - threshold and c2[1] <= c1[1] + threshold and
        c2[2] >= c1[2] - threshold and c2[2] <= c1[2] + threshold
    )

# %%
def removeBackground(img):
    global bgRemoveCounter
    global totalCounter
    imgData = img.getdata()
    m = mode(imgData)
    count = op.countOf(imgData, m)
    totalPixels = len(imgData)
    colorPercentage = count / totalPixels

    if(colorPercentage >= backgroundColorPercentage):
        bgRemoveCounter += 1
        newData = []
        for pix in imgData:
            if(equalsThreshold(m, pix, 60)):
                newData.append((0, 0, 0, 0))
            else:
                newData.append((pix[0], pix[1], pix[2], pix[3]))
            
        
        img.putdata(newData)

    totalCounter += 1    
    return img

# %%
def cleanImagesInDir(dir):
    files = os.listdir(dir)
    subdir = dir.removeprefix(f'{imageDir}')

    if subdir.startswith(os.sep):
        subdir = subdir[1:]

    newdir = os.path.join(outputDir, subdir)

    oppositeSep = '\\' if os.sep != '\\' else '/'
    newdir = newdir.replace(oppositeSep, os.sep)

    try:
        os.mkdir(newdir)
    except:
        pass

    for file in files:
        listedFile = os.path.join(dir, file)
        if os.path.isdir(listedFile):
            cleanImagesInDir(listedFile)
            continue

        try:
            img = Image.open(listedFile)
            img = img.convert("RGBA")
            img = removeBackground(img)
            fileName = file.split('/')[-1]
            fileName = fileName.split('.')[0] + '.png'
            savedir = os.path.join(newdir, fileName)
            img.save(savedir, 'PNG')
            print(f'saving: {savedir}')
        except Exception as e:
            print(f'Exception converting {listedFile} ==> {e}')

# %%
cleanImagesInDir(imageDir)
print(f"Done! Removed bakgrounds from {bgRemoveCounter} out of {totalCounter} images")
# Out:
# saving: ..\..\cleanedImg\bench press bench\000_weider-weight-bench-vs-marcy-weight-bench-52bb91.png
# saving: ..\..\cleanedImg\bench press bench\100945-8255462.png
# saving: ..\..\cleanedImg\bench press bench\100945-8255472.png
# saving: ..\..\cleanedImg\bench press bench\10213980.png
# saving: ..\..\cleanedImg\bench press bench\132659721-gym-bench-with-barbell-isolated-on-white-background-isometric-view.png
# saving: ..\..\cleanedImg\bench press bench\1636385359-314B59TcAeL.png
# saving: ..\..\cleanedImg\bench press bench\1_182ce0e5-5975-4f07-8661-2df8a56be891_1200x.png
# saving: ..\..\cleanedImg\bench press bench\20200930-Bench-03.png
# saving: ..\..\cleanedImg\bench press bench\21bab837-2d92-4db3-92b3-dc22c1a54500.png
# saving: ..\..\cleanedImg\bench press bench\3105.png
# saving: ..\..\cleanedImg\bench press bench\3105_xlg.png
# saving: ..\..\cleanedImg\bench press bench\31c621f8c58950c72881760caa1324ee08.png
# saving: ..\..\cleanedImg\bench press bench\31mzDe7hjRL.png
# saving: ..\..\cleanedImg\bench press bench\31pdkDr6eZL.png
# saving: ..\..\cleanedImg\bench press bench\3c5af7be-9c2e-441e-8f34-84f51a9bf734.png
# saving: ..\..\cleanedImg\bench press bench\417XsIy+HML.png
# saving: ..\..\cleanedImg\bench press bench\419Lyv24deL.png
# saving: ..\..\cleanedImg\bench press bench\41bg-iPD+hL.png
# saving: ..\..\cleanedImg\bench press bench\41Gumo1iH1L.png
# saving: ..\..\cleanedImg\bench press bench\41NSWr9RarL.png
# saving: ..\..\cleanedImg\bench press bench\41qq98CY0hL.png
# saving: ..\..\cleanedImg\bench press bench\41V4MPLyqKL.png
# saving: ..\..\cleanedImg\bench press bench\41WPZbfHeKL.png
# saving: ..\..\cleanedImg\bench press bench\41wtId3g6NL.png
# saving: ..\..\cleanedImg\bench press bench\41XUp9aqGpL.png
# saving: ..\..\cleanedImg\bench press bench\4201_9201PowerLiftingBench.png
# saving: ..\..\cleanedImg\bench press bench\44e18285-56c3-4440-a521-863d3bcaba3c.png
# saving: ..\..\cleanedImg\bench press bench\48006-york-fts-olympic-flat-bench1.png
# saving: ..\..\cleanedImg\bench press bench\52501_CHARCOALGREY.png
# saving: ..\..\cleanedImg\bench press bench\54038-55038-OlympicInclineBenchGunRacks.png
# saving: ..\..\cleanedImg\bench press bench\5cce415e-70ce-4cb6-ab3b-c503a831bf80.png
# saving: ..\..\cleanedImg\bench press bench\61cdH1ssaML.png
# saving: ..\..\cleanedImg\bench press bench\61N3XAZe+6L.png
# saving: ..\..\cleanedImg\bench press bench\61rwSlGnomL.png
# saving: ..\..\cleanedImg\bench press bench\61YCRnoXleL.png
# saving: ..\..\cleanedImg\bench press bench\6Q4A6698-Edit.png
# saving: ..\..\cleanedImg\bench press bench\71DmPT-vGGL.png
# saving: ..\..\cleanedImg\bench press bench\71Gj4j0N-NL.png
# saving: ..\..\cleanedImg\bench press bench\82b3ddeb-0753-4d42-aa89-bab3927c1e74.png
# saving: ..\..\cleanedImg\bench press bench\83bda2ef-c528-444b-98ca-774c42432234_4.png
# saving: ..\..\cleanedImg\bench press bench\9d3f840ad8fee0d27cc5917be3c3be46f8.png
# saving: ..\..\cleanedImg\bench press bench\a0398909-8d58-4aa1-899d-f32e7ba5e84a.png
# saving: ..\..\cleanedImg\bench press bench\A4-1.png
# saving: ..\..\cleanedImg\bench press bench\AB-5200-MetallicBlack-thumbnail_350x350.png
# saving: ..\..\cleanedImg\bench press bench\acd02e92-8805-4eb8-af8f-5799559fe8ad_2.png
# saving: ..\..\cleanedImg\bench press bench\Adjustable-Bench-Press-A4-1.png
# saving: ..\..\cleanedImg\bench press bench\b4c63909-fdfe-453d-a395-d5eaeb9ee2cf.png
# saving: ..\..\cleanedImg\bench press bench\bench-press-01.png
# saving: ..\..\cleanedImg\bench press bench\bench-press-500x500.png
# saving: ..\..\cleanedImg\bench press bench\bench-press.png
# saving: ..\..\cleanedImg\bench press bench\Benches__Racks_Olympic_Bench_Press-60.png
# saving: ..\..\cleanedImg\bench press bench\benchpress_283932233_1000.png
# saving: ..\..\cleanedImg\bench press bench\Bench_Press_1000_0001.png
# saving: ..\..\cleanedImg\bench press bench\BF-49_1-Main_620x.png
# saving: ..\..\cleanedImg\bench press bench\BFOB10r-Hero.png
# saving: ..\..\cleanedImg\bench press bench\d5b14d8f-4d24-4cac-88d0-e57f21ed676c_2.png
# saving: ..\..\cleanedImg\bench press bench\d7710783-f2e8-4706-9838-5447da9c2f64_3.png
# saving: ..\..\cleanedImg\bench press bench\d9b0e3ec7b0a4b49cb4e17419b286f20c6-marcyweightbench.png
# saving: ..\..\cleanedImg\bench press bench\e8eaa604-35b7-40bc-a63e-01de4e67d341.png
# saving: ..\..\cleanedImg\bench press bench\eb44b424-8d7d-4de5-96c6-a71a26639842.png
# saving: ..\..\cleanedImg\bench press bench\f0419624-c896-46f7-aa45-03236be219f7.png
# saving: ..\..\cleanedImg\bench press bench\FIT-E-BENCH-90-AB-06_3be502de-6a96-4482-87b6-32790870d07a.png
# saving: ..\..\cleanedImg\bench press bench\FIT-I-BENCH-S-00_c5f8e8e2-3a67-4776-a09c-36c7fb0e09a6.png
# saving: ..\..\cleanedImg\bench press bench\FIT-I-BENCH-S-01_e46b856f-3895-4eda-995c-c054cc3fedd5.png
# saving: ..\..\cleanedImg\bench press bench\Fixed-Olympic-Bench-PB720.png
# saving: ..\..\cleanedImg\bench press bench\GUEST_117e1757-7a39-41a6-8d2a-4ae66f988538.png
# saving: ..\..\cleanedImg\bench press bench\GUEST_26ed8121-1cf5-4a44-b87f-532ced4eb18d.png
# saving: ..\..\cleanedImg\bench press bench\gym-benches-and-weight-racks.png
# saving: ..\..\cleanedImg\bench press bench\Hb31750a67faa44c1b9791ac1045b3684v.png
# saving: ..\..\cleanedImg\bench press bench\hs025_olympic_flat_bench_1600.png
# saving: ..\..\cleanedImg\bench press bench\HTB1dqxuvIuYBuNkSmRyq6AA3pXaq.png
# saving: ..\..\cleanedImg\bench press bench\HTB1NZNiXoLrK1Rjy1zbq6AenFXaL.png
# saving: ..\..\cleanedImg\bench press bench\KB06RI-047--foldable-flat-bench--0.png
# saving: ..\..\cleanedImg\bench press bench\MIRAFIT%20M1%20FOLDING%20WEIGHT%20BENCH%20WITH%20DIP%20STATION.png
# saving: ..\..\cleanedImg\bench press bench\OLYMPIC-BENCH-PRESS1.png
# saving: ..\..\cleanedImg\bench press bench\olympic-flat-bench-press-500x500.png
# saving: ..\..\cleanedImg\bench press bench\OlympicBennch.png
# saving: ..\..\cleanedImg\bench press bench\PPF-707-Olympic-Flat-bench-xlg.png
# saving: ..\..\cleanedImg\bench press bench\Production-Sale-Weight-Bench-Bench-Stand-Multi-functional-Multi-function-Gym-Equipment-Wholesale-Home-Fitness-Equipment.png
# saving: ..\..\cleanedImg\bench press bench\s-l500.png
# saving: ..\..\cleanedImg\bench press bench\SCS01.png
# saving: ..\..\cleanedImg\bench press bench\TuffStuff-Evolution-Olympic-Bench-with-Safety-Stoppers-800x800.png
# saving: ..\..\cleanedImg\bench press bench\TuffStuff-Evolution-Olympic-Bench-with-Safety-Stoppers.png
# saving: ..\..\cleanedImg\bench press bench\valor-fitness-bd-2-bench-press-stands-1_7b859231-74b5-40e5-91db-a8d46a952899.png
# saving: ..\..\cleanedImg\bench press bench\valor-fitness-bd-2-bench-press-stands-1_7b859231-74b5-40e5-91db-a8d46a952899_360x.png
# saving: ..\..\cleanedImg\bench press bench\WB20_Maximale_Belastbaarheid.png
# saving: ..\..\cleanedImg\bench press bench\weight-bench-wb20.png
# saving: ..\..\cleanedImg\bench press bench\WeightBenchPRO.png
# saving: ..\..\cleanedImg\bench press bench\WINNOW%20Adjustable%20Weight%20Bench.png
# saving: ..\..\cleanedImg\bench press bench\WorkoutBench28.png
# saving: ..\..\cleanedImg\gym cable machine\290e9a42-7aa6-4899-8d91-ceeb32335163.png
# saving: ..\..\cleanedImg\gym cable machine\31-J3F++DML.png
# saving: ..\..\cleanedImg\gym cable machine\400717_01.png
# saving: ..\..\cleanedImg\gym cable machine\400868_01.png
# saving: ..\..\cleanedImg\gym cable machine\41-Oq242m7L.png
# saving: ..\..\cleanedImg\gym cable machine\41HD4DvFqaL.png
# saving: ..\..\cleanedImg\gym cable machine\4568282.png
# saving: ..\..\cleanedImg\gym cable machine\51baZxyTaCL.png
# saving: ..\..\cleanedImg\gym cable machine\51g0Lzuty-L.png
# saving: ..\..\cleanedImg\gym cable machine\55017_Cable_Cross.png
# saving: ..\..\cleanedImg\gym cable machine\6023_B.png
# saving: ..\..\cleanedImg\gym cable machine\6280A-6-STATION-SINGLE-POD-WITH-CROSS-OVER-300x300.png
# saving: ..\..\cleanedImg\gym cable machine\6PC3typU.png
# saving: ..\..\cleanedImg\gym cable machine\71ahWnfrIaL.png
# saving: ..\..\cleanedImg\gym cable machine\7AF877BA-FA6E-44D2-A702-25C280090D4D_1_201_a_300x300.png
# saving: ..\..\cleanedImg\gym cable machine\81zTYBjdgML.png
# saving: ..\..\cleanedImg\gym cable machine\8373b84ae8acab63bc6966b5ae27c678.png
# saving: ..\..\cleanedImg\gym cable machine\8ff75aacdb262d91f2c83783afed0001--home-gyms-cable.png
# saving: ..\..\cleanedImg\gym cable machine\9187096_R_Z001A.png
# saving: ..\..\cleanedImg\gym cable machine\960_xlg.png
# saving: ..\..\cleanedImg\gym cable machine\965-HI_1024x1024_7942de64-01e1-4a44-9e3d-f625b177d37c-401782_800x.png
# saving: ..\..\cleanedImg\gym cable machine\9NP-M9201-13BZS__58745.png
# saving: ..\..\cleanedImg\gym cable machine\BFCCO10_DSF3660-cut.png
# saving: ..\..\cleanedImg\gym cable machine\body-solid-scc1200g-pro-clubline-cable-crossover-44.png
# saving: ..\..\cleanedImg\gym cable machine\Body-SolidSCC1200GProClubCableCrossover3DView_512x512.png
# saving: ..\..\cleanedImg\gym cable machine\buge-8-stack-jungle-gym.png
# saving: ..\..\cleanedImg\gym cable machine\cabc1_1600.png
# saving: ..\..\cleanedImg\gym cable machine\cable-crossovers-18.png
# saving: ..\..\cleanedImg\gym cable machine\cable-machines-240x240.png
# saving: ..\..\cleanedImg\gym cable machine\cable.png
# saving: ..\..\cleanedImg\gym cable machine\CableCrossoverJ608.png
# saving: ..\..\cleanedImg\gym cable machine\cable_crossover-500x500.png
# saving: ..\..\cleanedImg\gym cable machine\CS-SigCbleMo_CMACO-hero.png
# saving: ..\..\cleanedImg\gym cable machine\CT-CCO.png
# saving: ..\..\cleanedImg\gym cable machine\CT-CCOS-2__75530.png
# saving: ..\..\cleanedImg\gym cable machine\download-1-copy.png
# saving: ..\..\cleanedImg\gym cable machine\download-2-copy.png
# saving: ..\..\cleanedImg\gym cable machine\dual-adjustable-pulley-cmdap-copy.png
# saving: ..\..\cleanedImg\gym cable machine\FT-CCOMF.png
# saving: ..\..\cleanedImg\gym cable machine\G7-home-gym-man-exercising-1000x1000_1800x1800.png
# saving: ..\..\cleanedImg\gym cable machine\hft_front_dg_shadow_600.png
# saving: ..\..\cleanedImg\gym cable machine\HR-SMWCC-1-1000x1000-1.png
# saving: ..\..\cleanedImg\gym cable machine\HTB1rTtOXvLsK1Rjy0Fbq6xSEXXaP.png
# saving: ..\..\cleanedImg\gym cable machine\legend-fitness-1131-cable-crossover.png
# saving: ..\..\cleanedImg\gym cable machine\legend-fitness-cable-crossover-plus-960-4.png
# saving: ..\..\cleanedImg\gym cable machine\LFCABLECROSS-2T.png
# saving: ..\..\cleanedImg\gym cable machine\Life-Fitness-Adjustable-Cable-Crossover-Machine.png
# saving: ..\..\cleanedImg\gym cable machine\Life-Fitness-Cable-Motion-Adjustable-Cable-Crossover.png
# saving: ..\..\cleanedImg\gym cable machine\Life-Fitness-Cable-Motion-Adjustable-Crossover.png
# saving: ..\..\cleanedImg\gym cable machine\life-fitness-signature-adj-cable-crossover.png
# saving: ..\..\cleanedImg\gym cable machine\life-fitness-signature-cable-motion-adjustable-cable-crossover.png
# saving: ..\..\cleanedImg\gym cable machine\Life-Fitness-Signature-Series-Adjustable-Fixed-Crossover.png
# saving: ..\..\cleanedImg\gym cable machine\mj5.png
# saving: ..\..\cleanedImg\gym cable machine\mj8.png
# saving: ..\..\cleanedImg\gym cable machine\PC-ACCWM-1000x1000-1.png
# saving: ..\..\cleanedImg\gym cable machine\REP-FT-5000.png
# saving: ..\..\cleanedImg\gym cable machine\sig-cmdap-bmet-mod-hero-copy.png
# saving: ..\..\cleanedImg\gym cable machine\Signature-Series-Adjustable-Cable-Crossover.png
# saving: ..\..\cleanedImg\gym cable machine\signatureseries-cable-motion-adjustable-cable-crossover-l-data.png
# saving: ..\..\cleanedImg\gym cable machine\signatureseries-cable-motion-adjustable-cable-crossover-l.png
# saving: ..\..\cleanedImg\gym cable machine\signature_series_adjustable_cable_crossover_413x@3x.png
# saving: ..\..\cleanedImg\gym cable machine\synrgy90-cable-cable-unit-1000x1000.png
# saving: ..\..\cleanedImg\gym cable machine\synrgy90-versa-cable-unit-1000x1000.png
# saving: ..\..\cleanedImg\gym cable machine\tag-fitness-elite-commercial-cable-crossover__29424.png
# saving: ..\..\cleanedImg\gym cable machine\valor-fitness-bd-61-cable-crossover-machine-1_d07e5856-3135-4853-8965-1f9aabdabef9.png
# saving: ..\..\cleanedImg\gym cable machine\valor-fitness-bd-61attb-cable-crossover-machine-w-attachment-bundle-1_900x.png
# saving: ..\..\cleanedImg\gym cable machine\valor-fitness-bd-62-main-2022.png
# saving: ..\..\cleanedImg\gym cable machine\valor-fitness-bd-7bcc-power-rack-with-lat-pull-and-cable-crossover-attachments-1.png
# saving: ..\..\cleanedImg\gym cable machine\Valor-Fitness-CB-12-Plate-Loaded-Lat-Pull-Down-Machine-1_400x400_crop_center.png
# saving: ..\..\cleanedImg\gym cable machine\web1-30.png
# saving: ..\..\cleanedImg\gym cable machine\web66-2.png
# Done! Removed bakgrounds from 146 out of 161 images
